# %% [markdown]
# # Course Project
#
# ## SIR-model - attempt to explanation
#
# This is attempt to make a work, in which we want to present epidemical equation-SIR-model.We will make representation of three differential equations who describe this SIR-model, and want to see how it works with different data.
# The differential equations in SIR-model are three:
#
# ## $ \frac {dS} {dt} = - \frac {bSI} {N} $
#
# ## $ \frac {dI} {dt} =  \frac {bSI} {N} - gI $
#
# ## $ \frac {dR} {dt} = gI $
#
#
# At first time these equations are invent from Kermack and MacKendrick in 1927.They use real data from epidemic situations in India, like a part from Britain empire.Why is the name "SIR-model"? SIR-model is made from abreviature from S,I and R initial letters.S is name of suscptabled, I come from infected, and R is recovered.There is some other infections models like SIS,SEIR but our work will be focused on SIR-model.This is [a link](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2199446/pdf/jhyg00216-0058.pdf) to one work of Kermack & MacKendrick, with some upgrades!Here is present with some strange notation the original equations(p.274).

# %%
import scipy.integrate
import numpy as np
import matplotlib.pyplot as plt

# %%
def SIR_model(y, t, beta, gamma):
    S, I, R = y
    
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - gamma * I
    dR_dt = gamma * I
    
    return([dS_dt, dI_dt, dR_dt])

S0 = 0.9
I0 = 0.1
R0 = 0.0
beta = 0.35
gamma = 0.1

t = np.linspace(0, 100, 10000)

solution = scipy.integrate.odeint(SIR_model, [S0, I0, R0], t, args=(beta, gamma))
solution = np.array(solution)

plt.figure(figsize=[6, 4])
plt.plot(t, solution[:, 0], label="S(t)")
plt.plot(t, solution[:, 1], label="I(t)")
plt.plot(t, solution[:, 2], label="R(t)")
plt.grid()
plt.legend()
plt.xlabel("Time")
plt.ylabel("Proportions")
plt.title("SIR model")
plt.show()

# %% [markdown]
# In this exam SIR-model is widthout N wich is total number of population.This explanation is from [here](https://www.youtube.com/watch?v=wEvZmBXgxO0).What is made here!At first we define a function, and name it "SIR-model", and we will use four paramerers:y, t(time), and beta and gamma wich are constants!Next is to describe differencial equations, who will be solved!At last for function we can close it with "return"!In return-mode we include initials of differencial equations, closed in two types of brackets...Next is to present initial conditions(our data section)!Then is time vector with parameters...In "solution" section we solve all (in only two slices of code), with help of scipy.integrate.odeint-commande mode, and numpy array.At last - with 10 orders of code we make "the visible part", the visualization and graphic mode!At the end what is tne final result:what is on the graphic!??Two from the three lines are simmlar like sigmoidal lines.Status of third line is line with growth and pick from 0 to 20 (days) and slow go to 0 at the end (near 100 days).All in these graphic is connection with time and proportion (the "mix") of three parts:1.Susceptable, 2.Infected, 3.Recovered, wich are presented here with coefficients.As a part of ready use "materal", we can make attempt to solve numerical these differencial equations and see data from solving!

# %%
def SIR_model(y, t, beta, gamma):
    S, I, R = y
    
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - gamma * I
    dR_dt = gamma * I
    
    return([dS_dt, dI_dt, dR_dt])

S0 = 0.9
I0 = 0.1
R0 = 0.0
beta = 0.35
gamma = 0.1

t = np.linspace(0, 100, 10000)

solution = scipy.integrate.odeint(SIR_model, [S0, I0, R0], t, args=(beta, gamma))
solution = np.array(solution)


print(solution)
# Out:
# [[9.00000000e-01 1.00000000e-01 0.00000000e+00]
#  [8.99684685e-01 1.00215198e-01 1.00117630e-04]
#  [8.99368802e-01 1.00430747e-01 2.00450648e-04]
#  ...
#  [3.02426304e-02 2.88052351e-04 9.69469317e-01]
#  [3.02425999e-02 2.87794879e-04 9.69469605e-01]
#  [3.02425694e-02 2.87537637e-04 9.69469893e-01]]

# %%
def SIR_model(y, t, beta, gamma):
    S, I, R = y
    
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - gamma * I
    dR_dt = gamma * I
    
    return([dS_dt, dI_dt, dR_dt])

S0 = 0.9
I0 = 0.1
R0 = 0.0
beta = 0.35
gamma = 0.1

t = np.linspace(0, 100, 10000)

solution = scipy.integrate.odeint(SIR_model, [S0, I0, R0], t, args=(beta, gamma))
solution = np.array(solution)


print(solution)
plt.hist(solution)
plt.xlabel("Proportions")
plt.ylabel("Number of people")
plt.show()
# Out:
# [[9.00000000e-01 1.00000000e-01 0.00000000e+00]
#  [8.99684685e-01 1.00215198e-01 1.00117630e-04]
#  [8.99368802e-01 1.00430747e-01 2.00450648e-04]
#  ...
#  [3.02426304e-02 2.88052351e-04 9.69469317e-01]
#  [3.02425999e-02 2.87794879e-04 9.69469605e-01]
#  [3.02425694e-02 2.87537637e-04 9.69469893e-01]]

# %% [markdown]
# Here we solve numerical the differential equations in numpy array.For remembering here is diferent value of the coefficients beta and gamma.Beta is contact rate and gamma is mean recovery rate.We can make some attempts with different data of beta and gamma!

# %%
def SIR_model(y, t, beta, gamma):
    S, I, R = y
    
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - gamma * I
    dR_dt = gamma * I
    
    return([dS_dt, dI_dt, dR_dt])

S0 = 0.9
I0 = 0.1
R0 = 0.0
beta = 0.40
gamma = 0.2

t = np.linspace(0, 100, 10000)

solution = scipy.integrate.odeint(SIR_model, [S0, I0, R0], t, args=(beta, gamma))
solution = np.array(solution)


print(solution)
plt.hist(solution)
plt.xlabel("Proportions")
plt.ylabel("Number of people")
plt.show()
# Out:
# [[9.00000000e-01 1.00000000e-01 0.00000000e+00]
#  [8.99639748e-01 1.00160072e-01 2.00180102e-04]
#  [8.99279064e-01 1.00320255e-01 4.00680487e-04]
#  ...
#  [1.71713849e-01 3.43668985e-06 8.28282714e-01]
#  [1.71713847e-01 3.43217973e-06 8.28282721e-01]
#  [1.71713844e-01 3.42767552e-06 8.28282728e-01]]

# %% [markdown]
# At last for these model we present the histogram with diferent data. When we have diferent value of coefficients,this is one variant.When contact rate began up the speed of infecions is up too!(In the beganing of epidemic).The conclusion from data in these histogram is that disistribution of paramethers will be near to bimodal disrtibution.The basic logic in SIR-model is that - in the start of epidemy in time we have a big growth of infected, we have a pick of the infected, and then we have slow move down of the infected.At the end of time, number of infected go to 0!In real conditions there is a infection temp named wave, and there is a lockdowns (social isolation), and vacsination works.This is not include in our SIR-model presentations.About accurancy of the model we know that Black Death done in Europe in period of 1347-1351-this is near 4 years and reduse population with 51%! Informaton come from [here](https://www.visualcapitalist.com/history-of-pandemics-deadliest/).In past years in the middle ages there where no statistical data about population.If we have exact data we will see forecast value of the model.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1000
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.2, 1./10 
# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S/1000, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/1000, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/1000, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %% [markdown]
# This label is from [here](https://scipython.com/book/chapter-8-scipy/additional-examples/the-sir-epidemic-model/).The differents from first model here is a number of population N,which in these model is 1000 people.Next is that time is different too, at first model is 100 days, in second model is 160 days.Like at first model, base solved metod is use odeint, and all part of equations are solved in two orders of code (without graphic presentation)!

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1000
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.2, 1./10 
# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

print(ret)
plt.hist(ret)
plt.xlabel("Population")
plt.ylabel("Time")
plt.show()
# Out:
# [[9.99000000e+02 1.00000000e+00 0.00000000e+00]
#  [9.98788525e+02 1.10562053e+00 1.05854624e-01]
#  [9.98554771e+02 1.22234204e+00 2.22887057e-01]
#  [9.98296409e+02 1.35131910e+00 3.52271529e-01]
#  [9.98010872e+02 1.49382365e+00 4.95304260e-01]
#  [9.97695328e+02 1.65125635e+00 6.53415861e-01]
#  [9.97346656e+02 1.82515884e+00 8.28184864e-01]
#  [9.96961420e+02 2.01722707e+00 1.02135261e+00]
#  [9.96535835e+02 2.22932557e+00 1.23483935e+00]
#  [9.96065735e+02 2.46350299e+00 1.47076225e+00]
#  [9.95546537e+02 2.72200860e+00 1.73145449e+00]
#  [9.94973204e+02 3.00730991e+00 2.01948643e+00]
#  [9.94340200e+02 3.32211145e+00 2.33768850e+00]
#  [9.93641449e+02 3.66937465e+00 2.68917603e+00]
#  [9.92870285e+02 4.05233860e+00 3.07737618e+00]
#  [9.92019401e+02 4.47454174e+00 3.50605688e+00]
#  [9.91080798e+02 4.93984426e+00 3.97935818e+00]
#  [9.90045723e+02 5.45245089e+00 4.50182568e+00]
#  [9.88904620e+02 6.01693383e+00 5.07844642e+00]
#  [9.87647058e+02 6.63825544e+00 5.71468698e+00]
# ...

# %% [markdown]
# After numerical solving and ploting a histogram,here are the same results like in previouse model.

# %%
import scipy.integrate as spi
import numpy as np
import pylab as pl
# %matplotlib inline

beta=1.4247
gamma=0.14286
TS=1.0
ND=70.0
S0=1-1e-6
I0=1e-6
INPUT = (S0, I0, 0.0)

def diff_eqs(INP,t):  
         '''The main set of equations'''
         Y = np.zeros((3))
         V = INP    
         Y[0] = - beta * V[0] * V[1]
         Y[1] = beta * V[0] * V[1] - gamma * V[1]
         Y[2] = gamma * V[1]
         return Y 
            

t_start = 0.0; t_end = ND; t_inc = TS
t_range = np.arange(t_start, t_end+t_inc, t_inc)
RES = spi.odeint(diff_eqs,INPUT,t_range)
#Ploting
pl.subplot(211)
pl.plot(RES[:,0], '-g', label='Susceptibles')
pl.plot(RES[:,2], '-k', label='Recovereds')
pl.legend(loc=0)
pl.title('Program_2_1.py')
pl.xlabel('Time')
pl.ylabel('Susceptibles and Recovereds')
pl.subplot(212)
pl.plot(RES[:,1], '-r', label='Infectious')
pl.xlabel('Time')
pl.ylabel('Infectious')
pl.show()

# %%
import scipy.integrate as spi
import numpy as np
import pylab as pl
# %matplotlib inline

beta=1.4247
gamma=0.14286
TS=1.0
ND=70.0
S0=1-1e-6
I0=1e-6
INPUT = (S0, I0, 0.0)

def diff_eqs(INP,t):  
         '''The main set of equations'''
         Y = np.zeros((3))
         V = INP    
         Y[0] = - beta * V[0] * V[1]
         Y[1] = beta * V[0] * V[1] - gamma * V[1]
         Y[2] = gamma * V[1]
         return Y 
            

t_start = 0.0; t_end = ND; t_inc = TS
t_range = np.arange(t_start, t_end+t_inc, t_inc)
RES = spi.odeint(diff_eqs,INPUT,t_range)

print(RES)
pl.hist(RES)
pl.show()
# Out:
# [[9.99999000e-01 1.00000000e-06 0.00000000e+00]
#  [9.99996055e-01 3.64966741e-06 2.95304063e-07]
#  [9.99985485e-01 1.31593559e-05 1.35516202e-06]
#  [9.99947369e-01 4.74532092e-05 5.17732698e-06]
#  [9.99809987e-01 1.71058575e-04 1.89549056e-05]
#  [9.99315303e-01 6.16116637e-04 6.85803972e-05]
#  [9.97537151e-01 2.21568587e-03 2.47163570e-04]
#  [9.91184992e-01 7.92727469e-03 8.87733548e-04]
#  [9.68987928e-01 2.78532303e-02 3.15884192e-03]
#  [8.97021359e-01 9.20814169e-02 1.08972243e-02]
#  [7.10533894e-01 2.55198783e-01 3.42673227e-02]
#  [4.16254892e-01 4.95859506e-01 8.78856016e-02]
#  [1.81009913e-01 6.47601951e-01 1.71388136e-01]
#  [7.02756394e-02 6.63464569e-01 2.66259791e-01]
#  [2.81753698e-02 6.13916972e-01 3.57907658e-01]
#  [1.23171971e-02 5.46803480e-01 4.40879323e-01]
#  [5.93052075e-03 4.79901640e-01 5.14167839e-01]
#  [3.12942081e-03 4.18601275e-01 5.78269304e-01]
#  [1.79337332e-03 3.64109920e-01 6.34096706e-01]
#  [1.10537879e-03 3.16274314e-01 6.82620307e-01]
# ...

# %% [markdown]
# The last model, what we want to present come from [here](http://epirecip.es/epicookbook/chapters/kr08/2_1/python_original).Time is on level of 70 days.The main set of equations is form help of numpy-zeros, and the base solve metod is too odeint! Zeros-array is one of Python way to solve differencal equation.After modify the result,at three models the distibutions are priviously the same(of the histograms)!
#
# At the end a conclusion may be on this order:1.We copy ready use data from different places in Internet.2.We make attempt to present and describe what it is.3.We make attempt to modify the code and present the results.(4.All non-autor data is citated from where come from)
